# %%
# imports

import requests

# %%
# Constants

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
# Create a messages list using the same format that we used for OpenAI

messages = [
    {"role": "user", "content": "Write powerpoint slides to describe website https://bbc.com"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Here is a suggested outline for a PowerPoint slide on the BBC website:
#
# **Slide 1: Title Slide**
#
# * Title: "BBC Website"
# * Subtitle: "A Global News and Media Organization"
# * Image: BBC logo
#
# **Slide 2: Overview**
#
# * Title: "About Us"
# * Text: "The BBC is a British public service broadcaster, providing news, current affairs, and entertainment content to over 100 countries worldwide."
# * Bullet points:
#  + Founded in 1922
#  + Available online since 1997
#  + Reaches over 400 million people globally
#
# **Slide 3: News Section**
#
# * Title: "News"
# * Text: "Stay up-to-date with the latest news from around the world, covering politics, business, entertainment, and more."
# * Image: Screenshot of BBC News homepage
# * Bullet points:
#  + Breaking news updates
#  + In-depth analysis and features
#  + Video and audio content
#
# **Slide 4: Programmes**
#
# * Title: "Programmes"
# * Text: "The BBC offers a wide range of television, radio, and online programmes, including dramas, comedies, documentaries, and more."
# * Image: Screenshot of BBC iPlayer or TV schedules page
# * Bullet points:
#  + Live and on-demand content
#  + Original productions from around the world
#  + Catch-up services
#
# **Slide 5: Services**
#
# * Title: "Services"
# * Text: "The BBC offers a range of online services, including radio stations, podcasts, and interactive features."
# * Image: Screenshot of BBC Radio website or podcast player
# * Bullet points:
#  + BBC Radio stations (e.g. 1Xtra, Radio 4)
#  + Podcasts and audio content
#  + Interactive features (e.g. quizzes, games)
#
# **Slide 6: Features**
#
# * Title: "Features"
# * Text: "The BBC offers a range of interactive features, including games, quizzes, and educational resources."
# * Image: Screenshot of BBC Games or Learn website
# * Bullet points:
#  + BBC Games (e.g. Football Matchday)
#  + Educational resources (e.g. CBBC, Learning Zone)
#  + Interactive content
#
# **Slide 7: Accessibility**
#
# * Title: "Accessibility"
# * Text: "The BBC strives to make its online services accessible to all users, including those with disabilities."
# * Image: Screenshot of BBC accessibility features (e.g. closed captions, audio descriptions)
# * Bullet points:
#  + Closed captions and subtitles
#  + Audio descriptions for visually impaired users
#  + Accessibility guidelines for developers
#
# **Slide 8: Innovation**
#
# * Title: "Innovation"
# * Text: "The BBC is committed to innovation and using technology to improve its services."
# * Image: Screenshot of BBC innovation initiatives (e.g. virtual reality, AI)
# * Bullet points:
#  + Virtual reality content
#  + Artificial intelligence-powered tools
#  + Experimentation with new formats and platforms
#
# **Slide 9: Impact**
#
# * Title: "Impact"
# * Text: "The BBC has a significant impact on global news and media, influencing public opinion and shaping cultural discourse."
# * Image: Graph or chart showing BBC's global reach
# * Bullet points:
#  + Global audience size and reach
#  + Influence on public opinion and policy debates
#  + Cultural significance of the BBC brand
#
# **Slide 10: Conclusion**
#
# * Title: "Conclusion"
# * Text: "The BBC website is a leading source of news, entertainment, and education content from around the world."
# * Image: BBC logo
# * Final thoughts or call to action

# %%
import ollama
import requests

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Here is a suggested PowerPoint slide layout and content to describe the BBC website:
#
# **Slide 1: Title Slide**
#
# * Title: "BBC Website: A Global Leader in News, Entertainment, and Education"
# * Subtitle: "Exploring the BBC's Online Presence"
# * Image: A logo of the British Broadcasting Corporation (BBC)
#
# **Slide 2: Introduction**
#
# * Title: "About the BBC"
# * Text: "The British Broadcasting Corporation (BBC) is a publicly funded broadcaster that has been a leading voice in news, entertainment, and education for over 90 years."
# * Bullet points:
#  + News programs: BBC News, BBC World News
#  + Entertainment programs: TV shows, radio shows, podcasts
#  + Education programs: Learn English, CBBC, CBeebies
#
# **Slide 3: Website Structure**
#
# * Title: "Website Structure"
# * Diagram or flowchart showing the main sections of the BBC website:
#  + Homepage
#  + News
#  + Entertainment
#  + Education
#  + Help and Feedback
# * Text: "The BBC website is divided into several main sections, each providing access to a range of content and services."
#
# **Slide 4: News Section**
#
# * Title: "News"
# * Image: A screenshot of the BBC News homepage
# * Text: "The news section provides up-to-date news coverage from around the world, including international stories, UK news, and feature articles."
# * Bullet points:
#  + BBC News: UK and international news
#  + BBC World News: Global news coverage
#  + Breaking News: Latest news updates
#
# **Slide 5: Entertainment Section**
#
# * Title: "Entertainment"
# * Image: A screenshot of a popular TV show or radio program on the BBC website
# * Text: "The entertainment section features a range of TV shows, radio programs, podcasts, and other content for adults and children."
# * Bullet points:
#  + TV Shows: dramas, comedies, documentaries
#  + Radio Shows: podcasts, live shows, playlists
#  + Entertainment Programs: music, arts, comedy
#
# **Slide 6: Education Section**
#
# * Title: "Education"
# * Image: A screenshot of a Learn English resource on the BBC website
# * Text: "The education section provides resources and programs for learners of all ages, including English language courses, educational videos, and interactive content."
# * Bullet points:
#  + Learn English: language courses and resources
#  + CBBC: children's entertainment and education
#  + CBeebies: preschool learning content
#
# **Slide 7: Mobile Optimization**
#
# * Title: "Mobile Optimization"
# * Image: A screenshot of the BBC website on a mobile device
# * Text: "The BBC website is optimized for mobile devices, providing easy access to news, entertainment, and education content on-the-go."
# * Bullet points:
#  + Responsive design
#  + Fast loading speeds
#  + Accessible navigation
#
# **Slide 8: Accessibility Features**
#
# * Title: "Accessibility Features"
# * Image: A screenshot of the BBC website with accessibility features enabled (e.g. text size adjustment)
# * Text: "The BBC website includes a range of accessibility features to ensure that all users can access and enjoy its content."
# * Bullet points:
#  + Text size adjustment
#  + High contrast mode
#  + Closed captions
#
# **Slide 9: Feedback and Help**
#
# * Title: "Feedback and Help"
# * Image: A screenshot of the BBC website's feedback form or help center
# * Text: "The BBC website provides easy access to feedback forms, FAQs, and other support resources for users."
# * Bullet points:
#  + Feedback form
#  + Help center
#  + Contact information
#
# **Slide 10: Conclusion**
#
# * Title: "Conclusion"
# * Text: "The BBC website is a comprehensive online resource that offers something for everyone, from news and entertainment to education and accessibility features."
# * Image: A logo of the British Broadcasting Corporation (BBC)

# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['Simage.jpg']
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2024-12-05T16:09:08.2545495Z' done=True done_reason='stop' total_duration=144260308100 load_duration=9394666700 prompt_eval_count=18 prompt_eval_duration=117649000000 eval_count=72 eval_duration=16923000000 message=Message(role='assistant', content='The image shows a strawberry plant with some leaves that have red spots and are turning yellow. The red spots could be rust, which can cause these symptoms on strawberry plants. Rust typically causes orange or red spots on the upper surface of the leaf. If you see these symptoms, it is recommended to remove all infected plants from your garden as soon as possible.', images=None, tool_calls=None)
